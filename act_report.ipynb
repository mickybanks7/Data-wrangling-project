# %% [markdown]
# ## Report: act_report

# %% [markdown]
# After carrying out all wrangling of the datasets, the final marged data was used to derive the following insights and visual.
#
# > The first insight carried out was to determine (Among the three predictions made by the algorithm, which of the predicting model predicted the Golden_Retriever dog type the most). This is paramount if we want to determine the dog breed with the most predicted outcome. The pandas `groupby` function was used at first to group the needed column and afterwards, sorted out using the `sort_values` function in pandas while parsing the ascending order to be false. This way, we get from the highest to the lowest value. Among the three predictions made, the `Golden_Retriever` was predicted more times than any other dog breed.
#
# > The second insight carried out was to know (Which dog stages has highest retweeted count). Since we know the most predicted dog breed, knowing the dog stages with the highest retweet became paramount as we curious to know if users retweeted the dogs uploaded at their first stage more or at other stages. From the insight in our wrangle_act, it shows that dogs at their forth stages `(pupper)` had more retweet_count.
#
# > The third insight carried out was to know (What month has the highest dog stages). The month coloumn was not available on any of the three datasets during the data gathering stages but as part of the wrangling process, a month column had to be created before a master dataset is derieved. Using the `groupby` and `sort_values` function, this was determined and it shows that the month of `December` had the highest post with dog stages. December is a holiday season and so, most people are usually available and always online and thus it is highly plusable.
#
# > The visuals was plotted using `seaborn borplot`. The barplot was used as we try to determine the `day` with the highest average rating_numerator. What this means is that on the average, there days where ratings of dogs posted where all most equally to or slightly above the average rating. below is a display of the graphical representation.

# %% [markdown]
# ![visual-2.png](attachment:visual-2.png)
